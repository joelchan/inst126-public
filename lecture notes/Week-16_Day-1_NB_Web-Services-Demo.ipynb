# %% [markdown]
# # Programming for the Web (teaser trailer demo)

# %%
# libraries for getting/retreieving data from the Web
import urllib.request, urllib.parse, urllib.error
# library for parsing the data we get from the Web
import bs4
import json
import pandas as pd

# %% [markdown]
# ## Using urllib to *CONNECT* to data from another computer

# %%
# url we want (it's like a file path!)
# course_list_url = "https://app.testudo.umd.edu/soc/202001/INST"
# course_list_url = "https://app.testudo.umd.edu/soc/search?courseId=INST&sectionId=&termId=202208&_openSectionsOnly=on&creditCompare=%3E%3D&credits=0.0&courseLevelFilter=ALL&instructor=&_facetoface=on&_blended=on&_online=on&courseStartCompare=&courseStartHour=&courseStartMin=&courseStartAM=&courseEndHour=&courseEndMin=&courseEndAM=&teachingCenter=ALL&_classDay1=on&_classDay2=on&_classDay3=on&_classDay4=on&_classDay5=on"
# make a request to the server computer, and store the response data packet in a variable
response = urllib.request.urlopen(course_list_url)

# %%
# response object behaves a bit like a file handler (remember?)
course_list_html = response.read()
course_list_html
# Out:
# b'\n\n\n\n\n<!doctype html>\n<!--[if lt IE 7]>\t<html lang="en-us" class="no-js ie6">\t<![endif]--> \n<!--[if IE 7]>\t\t<html lang="en-us" class="no-js ie7">\t<![endif]--> \n<!--[if IE 8]>\t\t<html lang="en-us" class="no-js ie8">\t<![endif]--> \n<!--[if gte IE 9]>\t<html lang="en-us" class="no-js ie9">\t<![endif]-->\n<!--[if !IE]> -->\t<html lang="en-us" class="no-js">\t<!-- <![endif]-->\n\t<head>\n\t\t\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n\t\t<meta charset="utf-8" />\n\t\t\n\t\t<title>\n\t\t\tSchedule of Classes\n\t\t</title>\n\t\t\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0" />\n\n\t\t<link rel="icon" type="image/x-icon" href="/soc/resources/images/favicon.ico">\n\t\t\n\t\t<link rel="stylesheet" href="/soc/resources/css/lib/jquery-ui-1.8.23-umd/jquery-ui-1.8.23-umd.css" type="text/css" media="screen" />\n\t\t<link rel="stylesheet" href="/soc/resources/css/umd.css" type="text/css" media="screen" />\n\t\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t<link rel="stylesheet" href="/soc/resources/css/soc.css" type="text/css" media="screen" />\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\t\n\t\t<!-- modernizr v2.6.2 -->\n\t\t<script type="text/javascript" src="/soc/resources/js/lib/modernizr-2.6.2.min.js"></script>\n\t\t\n\t\t<!-- css3-mediaqueries-js - http://code.google.com/p/css3-mediaqueries-js/ - Enables media queries in some unsupported browsers -->\n\t\t<script type="text/javascript" src="/soc/resources/js/lib/css3-mediaqueries.js"></script>\n\t\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t<script type="text/javascript" src="/soc/resources/js/lib/jquery-1.8.1.min.js"></script>\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t<script type="text/javascript" src="/soc/resources/js/lib/jquery-ui-1.8.23.min.js"></script>\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t<script type="text/javascript" src="/soc/resources/js/lib/jquery.ui.autocomplete.html.js"></script>\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t<script type="text/javascript" src="/soc/resources/js/lib/jquery.timeentry.pack.js"></script>\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t<script type="text/javascript" src="/soc/resources/js/lib/json2.js"></script>\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t<script type="text/javascript" src="/soc/resources/js/lib/jquery.cookie.js"></script>\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t<script type="text/javascript" src="/soc/resources/js/lib/jquery.pageslide.js"></script>\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t<script type="text/javascript" src="/soc/resources/js/my-saved-list.js"></script>\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t<script type="text/javascript" src="/soc/resources/js/soc.js"></script>\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t<script type="text/javascript" src="/soc/resources/js/lib/jquery.qtip-1.0.0-rc3.min.js"></script>\n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\t\n\t</head>\n\t\n\t<body>\n\n\t\t<div id="umd-frame-wrapper" class="container">\n\t\t\t\n\t\t\t<div id="umd-frame">\n\t\t\t\t\n\t\t\t\t\r\n\r\n<div id="header-wrapper">\r\n\t<div id="header" class="row">\r\n\t\t\r\n\t\t<div id="umd-logo" class="six columns">\r\n\t\t\t\r\n\t\t\t<a href="http://www.umd.edu/" target="_blank">\r\n\t\t\t\t<img src="/soc/resources/images/umd-logo.gif">\r\n\t\t\t</a>\r\n\t\t</div>\r\n\t\t\r\n\t\t\r\n\t\t\r\n\t\t\r\n\t\t\r\n\t</div>\r\n</div>\r\n\n\t\t\t\t\n\t\t\t\t<div id="umd-container">\n\t\t\t\t\t\n\t\t\t\t\t\r\n\r\n\r\n\r\n\r\n<div id="title-bar-wrapper" class="container">\r\n\t<div id="title-bar" class="row">\r\n\t\t\r\n\t\t<div id="mobile-umd-logo">\r\n\t\t\t<a href="http://www.umd.edu" target="_blank">\r\n\t\t\t\t<img src="/soc/resources/images/umd-informal-seal.png">\r\n\t\t\t</a>\r\n\t\t</div>\r\n\t\t\r\n\t\t<div id="app-title">\r\n\t\t\t\r\n\t\t\t\r\n\t\t\t\r\n\t\t\t<a href="/soc/">\r\n\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r ...

# %% [markdown]
# ## Using beautifulsoup to *PARSE* an HTML document we get from another computer

# %%
def html_to_course_list(html):
    """
    Get html page and parse out course info and dump into list of course entries
    Params:
    - html (str) - a str representation of an html page that lists courses from testudo
    Returns: courses: list of course entries, which can then be printed
    """
    
    print("Initializing html parser")
    # init parser
    soup = bs4.BeautifulSoup(html, 'html.parser')

    # to hold the course data
    courses = []

    print("Parsing all the courses...")
    # grab all the divs that have class 'course' (these are all the courses)
    # and iterate through them
    course_packets = soup.find_all(class_="course")
    print(course_packets)
    for course in course_packets:
        # code is the id of this div
        code = course.get('id')
        # title is in text of div that has class 'course-title'
        title = course.find(class_="course-title").text

        # grab the description and prereqs
        # all are of class `approved-course-text` with only in-text (not html) distinctions of type :/
        # so we gotta iterate through all the course texts and check for the prereq
        description = ""
        prereq = "None"
        # get all the divs that have class `approved-course-text` 
        # and iterate through them
        for descr in course.find_all(class_="approved-course-text"):
            # get the text of the div
            d_text = descr.text
            # it's prereq if it has `Prerequisite:` in it
            if "Prerequisite:" in d_text:
                # if it is, then set the value of prereq to this text
                prereq = d_text
            else: 
                # otherwise, add to the general course description text bundle
                description += d_text
        # credits in text of div that has class `course-min-credits`
        credits = course.find(class_="course-min-credits").text

        # ok now stitch all the data together into a dict to add 
        # as an entry for this course to our course data list
        courses.append({
            'Code': code,
            'Title': title,
            'Description': description,
            'Prereqs': prereq,
            'Credits': credits
        })
    return courses

# %%
# parse the html
course_list = html_to_course_list(course_list_html)
# display it
course_list[:5]
# Out:
# Initializing html parser
# Parsing all the courses...
# [<div class="course" id="INST101">
# <input name="courseId" type="hidden" value="INST101"/>
# <div class="row">
# <div class="course-id-container one columns">
# <div class="course-id">INST101</div>
# </div>
# <div class="course-info-container eleven columns">
# <div class="course-basic-info-container sixteen colgrid">
# <div class="row">
# <div class="thirteen columns">
# <span class="course-title">Bits and Bytes of Computer and Information Sciences</span>
# </div>
# <div class="two columns">
# <fieldset class="syllabus-fieldset">
# <legend>
# <a class="toggle-syllabus-link" href="">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-e"></span>
# <span class="toggle-sections-link-text">Syllabus Repository  </span>
# <span>(0)</span>
# <input name="courseId" type="hidden" value="INST101"/>
# </a>
# </legend>
# <div id="INST101-syllabus-container"></div>
# </fieldset>
# </div>
# <!-- @@@@@@@@@ -->
# <div class="course-action-links-container one columns">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST101', '*', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# </div>
# </div>
# <div class="course-stats-container row clearfix">
# <div class="course-credits-group two columns">
# <div>
# <span class="course-info-label">Credits:</span>
# <span class="course-min-credits">1</span>
# </div>
# </div>
# <div class="grading-method-group five columns">
# <div>
# <span class="course-info-label"><abbr title="Grading Method"><span>Grad Meth</span></abbr></span>:
# 														<span class="grading-method">
# <abbr title="Regular, Pass-Fail"><span>Reg, P-F</span></abbr>
# </span>
# </div>
# </div>
# <div class="core-codes-group two columns">
# <div>
# </div>
# </div>
# <div class="gen-ed-codes-group six columns">
# <div>
# </div>
# </div>
# </div>
# </div>
# <div class="approved-course-texts-container">
# <div class="row">
# <div class="twelve columns">
# <div class="approved-course-text"><div><div><div><strong>Restriction:</strong> For first time freshmen and first time transfer students. </div><div class="crosslisted-as"><strong>Cross-listed with:</strong> CMSC100. </div><div><strong>Credit only granted for:</strong> CMSC100 or INST101.</div></div></div></div>
# </div>
# </div>
# <div class="row">
# <div class="twelve columns">
# <div class="approved-course-text">Students are introduced to the fields (and disciplines) of computer science and information science within a small classroom setting. They will learn to make a successful transition from high school to the university, while exploring study skills, student success plans and research opportunities.</div>
# </div>
# </div>
# </div>
# <div class="course-texts-container">
# </div>
# <div class="toggle-sections-link-container">
# <div class="row">
# <div class="sections-fieldset-container twelve columns">
# <fieldset class="sections-fieldset sections-displayed">
# <legend>
# <a class="toggle-sections-link" href="/soc/202208/INST/INST101?teachingCenter=ALL">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-s"></span><span class="toggle-sections-link-text">Hide Sections</span>
# </a>
# <span class="hidden section-deliveryFilter">
# <a class="hidden delivery-all deliveryFilter deliveryFilter--selected" href="javascript:void(0)" onclick="SocJs.showAllSections(this);">All Sections</a>
# <a class="hidden delivery-f2f deliveryFilter" href="javascript:void(0)" onclick="SocJs.showF2FSections(this);">Face-to-Face</a>
# <a class="hidden delivery-blended deliveryFilter" href="javascript:void(0)" onclick="SocJs.showBlendedSections(this);"><img aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/blended_icon.png" width="20px"/>  Blended Learning</a>
# <a class="hidden delivery-online deliveryFilter" href="javascript:void(0)" onclick="SocJs.showOnlineSections(this);"><img aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/> Online</a>
# </span>
# </legend>
# <div class="sections-container">
# <div class="sections sixteen colgrid">
# <div class="section delivery-f2f">
# <input name="sectionId" type="hidden" value="0101"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0101
# 									</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Instructor: TBA</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">40</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">40</span>,
# 											</span>
# <span class="waitlist">
# <a href="http://www.registrar.umd.edu/current/registration/registration.html#waithold">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# </a>)
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST101', '0101', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="section-day-time-group push_two five columns">
# <span class="section-days">M</span>
# <span class="class-start-time">1:00pm</span> - <span class="class-end-time">1:50pm</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <a style="color:#A81919;" target="_blank"><span class="building-code">IRB</span>
# <span class="class-room">1207</span></a>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="section delivery-f2f">
# <input name="sectionId" type="hidden" value="0201"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0201
# 									</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Instructor: TBA</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">40</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">40</span>,
# 											</span>
# <span class="waitlist">
# <a href="http://www.registrar.umd.edu/current/registration/registration.html#waithold">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# </a>)
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST101', '0201', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png">
# </img></a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="section-day-time-group push_two five columns">
# <span class="section-days">F</span>
# <span class="class-start-time">11:00am</span> - <span class="class-end-time">11:50am</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <a style="color:#A81919;" target="_blank"><span class="building-code">CSI</span>
# <span class="class-room">1121</span></a>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </fieldset>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="course" id="INST104">
# <input name="courseId" type="hidden" value="INST104"/>
# <div class="row">
# <div class="course-id-container one columns">
# <div class="course-id">INST104</div>
# </div>
# <div class="course-info-container eleven columns">
# <div class="course-basic-info-container sixteen colgrid">
# <div class="row">
# <div class="thirteen columns">
# <span class="course-title">Design Across Campus</span>
# </div>
# <div class="two columns">
# <fieldset class="syllabus-fieldset">
# <legend>
# <a class="toggle-syllabus-link" href="">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-e"></span>
# <span class="toggle-sections-link-text">Syllabus Repository  </span>
# <span>(0)</span>
# <input name="courseId" type="hidden" value="INST104"/>
# </a>
# </legend>
# <div id="INST104-syllabus-container"></div>
# </fieldset>
# </div>
# <!-- @@@@@@@@@ -->
# <div class="course-action-links-container one columns">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST104', '*', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png">
# </img></a>
# </div>
# </div>
# <div class="course-stats-container row clearfix">
# <div class="course-credits-group two columns">
# <div>
# <span class="course-info-label">Credits:</span>
# <span class="course-min-credits">3</span>
# </div>
# </div>
# <div class="grading-method-group five columns">
# <div>
# <span class="course-info-label"><abbr title="Grading Method"><span>Grad Meth</span></abbr></span>:
# 														<span class="grading-method">
# <abbr title="Regular, Pass-Fail, Audit"><span>Reg, P-F, Aud</span></abbr>
# </span>
# </div>
# </div>
# <div class="core-codes-group two columns">
# <div>
# </div>
# </div>
# <div class="gen-ed-codes-group six columns">
# <div>
# </div>
# </div>
# </div>
# </div>
# <div class="approved-course-texts-container">
# <div class="row">
# <div class="twelve columns">
# <div class="approved-course-text">What is design, who does it, and how is it done? There is no one answer to this question--it depends on who you ask. The answers to these questions vary across disciplines and across the University campus. This course, designed with modules from contributors in UMD programs including Information Studies, Human-Computer Interaction, Graphic Design, Immersive Media Arts, Journalism, Architecture, Landscape Architecture, Engineering, and Policy, will introduce students to the goals and values, approaches, skills, and practices of diverse fields of design. It will enable students to identify grand challenges in design and serve as a sorting hat to help students find a design practice that matches their own values, approaches, skills and goals.</div>
# </div>
# </div>
# </div>
# <div class="course-texts-container">
# </div>
# <div class="toggle-sections-link-container">
# <div class="row">
# <div class="sections-fieldset-container twelve columns">
# <fieldset class="sections-fieldset sections-displayed">
# <legend>
# <a class="toggle-sections-link" href="/soc/202208/INST/INST104?teachingCenter=ALL">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-s"></span><span class="toggle-sections-link-text">Hide Sections</span>
# </a>
# <span class="hidden section-deliveryFilter">
# <a class="hidden delivery-all deliveryFilter deliveryFilter--selected" href="javascript:void(0)" onclick="SocJs.showAllSections(this);">All Sections</a>
# <a class="hidden delivery-f2f deliveryFilter" href="javascript:void(0)" onclick="SocJs.showF2FSections(this);">Face-to-Face</a>
# <a class="hidden delivery-blended deliveryFilter" href="javascript:void(0)" onclick="SocJs.showBlendedSections(this);"><img aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/blended_icon.png" width="20px"/>  Blended Learning</a>
# <a class="hidden delivery-online deliveryFilter" href="javascript:void(0)" onclick="SocJs.showOnlineSections(this);"><img aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/> Online</a>
# </span>
# </legend>
# <div class="sections-container">
# <div class="sections sixteen colgrid">
# <div class="section delivery-online">
# <input name="sectionId" type="hidden" value="0101"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0101
# 									</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Katie Shilton</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">50</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">25</span>,
# 											</span>
# <span class="waitlist">
# <a href="http://www.registrar.umd.edu/current/registration/registration.html#waithold">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# </a>)
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST104', '0101', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="one columns"><img aria-hidden="true" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/></div>
# <div class="section-day-time-group push_one five columns">
# <span class="section-days">Tu</span>
# <span class="class-start-time">2:00pm</span> - <span class="class-end-time">4:45pm</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <span class="class-room">ONLINE</span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </fieldset>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="course" id="INST123">
# <input name="courseId" type="hidden" value="INST123"/>
# <div class="row">
# <div class="course-id-container one columns">
# <div class="course-id">INST123</div>
# </div>
# <div class="course-info-container eleven columns">
# <div class="course-basic-info-container sixteen colgrid">
# <div class="row">
# <div class="thirteen columns">
# <span class="course-title">Databases for All</span>
# </div>
# <div class="two columns">
# <fieldset class="syllabus-fieldset">
# <legend>
# <a class="toggle-syllabus-link" href="">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-e"></span>
# <span class="toggle-sections-link-text">Syllabus Repository  </span>
# <span>(0)</span>
# <input name="courseId" type="hidden" value="INST123"/>
# </a>
# </legend>
# <div id="INST123-syllabus-container"></div>
# </fieldset>
# </div>
# <!-- @@@@@@@@@ -->
# <div class="course-action-links-container one columns">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST123', '*', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# </div>
# </div>
# <div class="course-stats-container row clearfix">
# <div class="course-credits-group two columns">
# <div>
# <span class="course-info-label">Credits:</span>
# <span class="course-min-credits">3</span>
# </div>
# </div>
# <div class="grading-method-group five columns">
# <div>
# <span class="course-info-label"><abbr title="Grading Method"><span>Grad Meth</span></abbr></span>:
# 														<span class="grading-method">
# <abbr title="Regular, Pass-Fail, Audit"><span>Reg, P-F, Aud</span></abbr>
# </span>
# </div>
# </div>
# <div class="core-codes-group two columns">
# <div>
# </div>
# </div>
# <div class="gen-ed-codes-group six columns">
# <div>
# <span class="course-info-label"><abbr title="General Education"><span>GenEd</span></abbr></span>:
#
#
#
#
#
#
# 																	<span class="course-subcategory">
# <a href="#" title="Distributive Studies - Scholarship in Practice">DSSP</a></span>
# </div>
# </div>
# </div>
# </div>
# <div class="approved-course-texts-container">
# <div class="row">
# <div class="twelve columns">
# <div class="approved-course-text"><div><div><div><strong>Restriction:</strong> Must not have completed or be currently taking INST327 or BMGT402.</div></div></div></div>
# </div>
# </div>
# <div class="row">
# <div class="twelve columns">
# <div class="approved-course-text">An introduction to relational databases for students with no previous programming experience. Provides a means for students of diverse backgrounds to successfully learn how to store, retrieve, and maintain data in relational databases. Topics include a brief comparison of database systems with an emphasis on relational databases, fundamental relational database concepts, and data types. Includes technical approaches to accessing information stored in relational databases.</div>
# </div>
# </div>
# </div>
# <div class="course-texts-container">
# </div>
# <div class="toggle-sections-link-container">
# <div class="row">
# <div class="sections-fieldset-container twelve columns">
# <fieldset class="sections-fieldset sections-displayed">
# <legend>
# <a class="toggle-sections-link" href="/soc/202208/INST/INST123?teachingCenter=ALL">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-s"></span><span class="toggle-sections-link-text">Hide Sections</span>
# </a>
# <span class="hidden section-deliveryFilter">
# <a class="hidden delivery-all deliveryFilter deliveryFilter--selected" href="javascript:void(0)" onclick="SocJs.showAllSections(this);">All Sections</a>
# <a class="hidden delivery-f2f deliveryFilter" href="javascript:void(0)" onclick="SocJs.showF2FSections(this);">Face-to-Face</a>
# <a class="hidden delivery-blended deliveryFilter" href="javascript:void(0)" onclick="SocJs.showBlendedSections(this);"><img aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/blended_icon.png" width="20px"/>  Blended Learning</a>
# <a class="hidden delivery-online deliveryFilter" href="javascript:void(0)" onclick="SocJs.showOnlineSections(this);"><img aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/> Online</a>
# </span>
# </legend>
# <div class="sections-container">
# <div class="sections sixteen colgrid">
# <div class="section delivery-f2f">
# <input name="sectionId" type="hidden" value="0101"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0101
# 									</span>
# <span class="footnote-marker">*</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Pamela Duffy</span>,
#
#
#
#
#
#
#
#
# 															<span class="section-instructor">Vedat Diker</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">29</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">1</span>,
# 											</span>
# <span class="waitlist has-waitlist">
# <a href="http://www.registrar.umd.edu/current/registration/registration.html#waithold">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# <span class="seats-info-label">Holdfile:</span>
# <span class="waitlist-count">3</span>
# </a>)
#
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST123', '0101', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="section-day-time-group push_two five columns">
# <span class="section-days">Tu</span>
# <span class="class-start-time">12:30pm</span> - <span class="class-end-time">1:45pm</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <a style="color:#A81919;" target="_blank"><span class="building-code">ESJ</span>
# <span class="class-room">2204</span></a>
# </span>
# </div>
# </div>
# <div class="row">
# <div class="section-day-time-group push_two five columns">
# <span class="section-days">Th</span>
# <span class="class-start-time">2:00pm</span> - <span class="class-end-time">3:15pm</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <a style="color:#A81919;" target="_blank"><span class="building-code">HBK</span>
# <span class="class-room">0103</span></a>
# </span>
# </div>
# <div class="two columns">
# <span class="class-type">Discussion</span>
# </div>
# </div>
# </div>
# </div>
# <div class="section delivery-f2f">
# <input name="sectionId" type="hidden" value="0102"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0102
# 									</span>
# <span class="footnote-marker">*</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Vedat Diker</span>,
#
#
#
#
#
#
#
#
# 															<span class="section-instructor">Pamela Duffy</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">28</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">4</span>,
# 											</span>
# <span class="waitlist has-waitlist">
# <a href="http://www.registrar.umd.edu/current/registration/registration.html#waithold">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# <span class="seats-info-label">Holdfile:</span>
# <span class="waitlist-count">2</span>
# </a>)
#
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST123', '0102', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png">
# </img></a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="section-day-time-group push_two five columns">
# <span class="section-days">Tu</span>
# <span class="class-start-time">12:30pm</span> - <span class="class-end-time">1:45pm</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <a style="color:#A81919;" target="_blank"><span class="building-code">ESJ</span>
# <span class="class-room">2204</span></a>
# </span>
# </div>
# </div>
# <div class="row">
# <div class="section-day-time-group push_two five columns">
# <span class="section-days">Th</span>
# <span class="class-start-time">3:00pm</span> - <span class="class-end-time">4:15pm</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <a style="color:#A81919;" target="_blank"><span class="building-code">ITV</span>
# <span class="class-room">1100</span></a>
# </span>
# </div>
# <div class="two columns">
# <span class="class-type">Discussion</span>
# </div>
# </div>
# </div>
# </div>
# <div class="section delivery-f2f">
# <input name="sectionId" type="hidden" value="0103"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0103
# 									</span>
# <span class="footnote-marker">*</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Pamela Duffy</span>,
#
#
#
#
#
#
#
#
# 															<span class="section-instructor">Vedat Diker</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">30</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">26</span>,
# 											</span>
# <span class="waitlist has-waitlist">
# <a href="http://www.registrar.umd.edu/current/registration/registration.html#waithold">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# <span class="seats-info-label">Holdfile:</span>
# <span class="waitlist-count">2</span>
# </a>)
#
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST123', '0103', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png">
# </img></a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="section-day-time-group push_two five columns">
# <span class="section-days">Tu</span>
# <span class="class-start-time">12:30pm</span> - <span class="class-end-time">1:45pm</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <a style="color:#A81919;" target="_blank"><span class="building-code">ESJ</span>
# <span class="class-room">2204</span></a>
# </span>
# </div>
# </div>
# <div class="row">
# <div class="section-day-time-group push_two five columns">
# <span class="section-days">Th</span>
# <span class="class-start-time">4:00pm</span> - <span class="class-end-time">5:15pm</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <a style="color:#A81919;" target="_blank"><span class="building-code">TYD</span>
# <span class="class-room">0102</span></a>
# </span>
# </div>
# <div class="two columns">
# <span class="class-type">Discussion</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footnote-container row">
# <div class="footnote twelve columns">
# <span class="footnote-marker">*</span>
# <span class="footnote-message">
#
#
#
# 									These sections are currently restricted to students with less than 60 credit hours completed. For further information, please click <a href="http://www.registrar.umd.edu/current/registration/seatmanagement.html" target="_blank">here</a>.
#
#
#
# 						</span>
# </div>
# </div>
# </div>
# </fieldset>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="course" id="INST126">
# <input name="courseId" type="hidden" value="INST126"/>
# <div class="row">
# <div class="course-id-container one columns">
# <div class="course-id">INST126</div>
# </div>
# <div class="course-info-container eleven columns">
# <div class="course-basic-info-container sixteen colgrid">
# <div class="row">
# <div class="thirteen columns">
# <span class="course-title">Introduction to Programming for Information Science</span>
# </div>
# <div class="two columns">
# <fieldset class="syllabus-fieldset">
# <legend>
# <a class="toggle-syllabus-link" href="">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-e"></span>
# <span class="toggle-sections-link-text">Syllabus Repository  </span>
# <span>(3)</span>
# <input name="courseId" type="hidden" value="INST126"/>
# </a>
# </legend>
# <div id="INST126-syllabus-container"></div>
# </fieldset>
# </div>
# <!-- @@@@@@@@@ -->
# <div class="course-action-links-container one columns">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST126', '*', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png">
# </img></a>
# </div>
# </div>
# <div class="course-stats-container row clearfix">
# <div class="course-credits-group two columns">
# <div>
# <span class="course-info-label">Credits:</span>
# <span class="course-min-credits">3</span>
# </div>
# </div>
# <div class="grading-method-group five columns">
# <div>
# <span class="course-info-label"><abbr title="Grading Method"><span>Grad Meth</span></abbr></span>:
# 														<span class="grading-method">
# <abbr title="Regular, Audit"><span>Reg, Aud</span></abbr>
# </span>
# </div>
# </div>
# <div class="core-codes-group two columns">
# <div>
# </div>
# </div>
# <div class="gen-ed-codes-group six columns">
# <div>
# </div>
# </div>
# </div>
# </div>
# <div class="approved-course-texts-container">
# <div class="row">
# <div class="twelve columns">
# <div class="approved-course-text"><div><div><div><strong>Prerequisite:</strong> Math placement of STAT100 or higher. </div><div><strong>Restriction:</strong> Must not have completed INST326; and must be in Information Science, Technology and Information Design, or Social Data Science programs.</div></div></div></div>
# </div>
# </div>
# <div class="row">
# <div class="twelve columns">
# <div class="approved-course-text">An introduction to computer programming for students with very limited or no previous programming experience. Topics include fundamental programming concepts such as variables, data types, assignments, arrays, conditionals, loops, functions, and I/O operations.</div>
# </div>
# </div>
# </div>
# <div class="course-texts-container">
# </div>
# <div class="toggle-sections-link-container">
# <div class="row">
# <div class="sections-fieldset-container twelve columns">
# <fieldset class="sections-fieldset sections-displayed">
# <legend>
# <a class="toggle-sections-link" href="/soc/202208/INST/INST126?teachingCenter=ALL">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-s"></span><span class="toggle-sections-link-text">Hide Sections</span>
# </a>
# <span class="hidden section-deliveryFilter">
# <a class="hidden delivery-all deliveryFilter deliveryFilter--selected" href="javascript:void(0)" onclick="SocJs.showAllSections(this);">All Sections</a>
# <a class="hidden delivery-f2f deliveryFilter" href="javascript:void(0)" onclick="SocJs.showF2FSections(this);">Face-to-Face</a>
# <a class="hidden delivery-blended deliveryFilter" href="javascript:void(0)" onclick="SocJs.showBlendedSections(this);"><img aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/blended_icon.png" width="20px"/>  Blended Learning</a>
# <a class="hidden delivery-online deliveryFilter" href="javascript:void(0)" onclick="SocJs.showOnlineSections(this);"><img aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/> Online</a>
# </span>
# </legend>
# <div class="sections-container">
# <div class="sections sixteen colgrid">
# <div class="section delivery-online">
# <input name="sectionId" type="hidden" value="0101"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0101
# 									</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Carrie Lindeman</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">54</span>,
# 											</span>
# <span class="open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">0</span>,
# 											</span>
# <span class="waitlist">
# <a href="http://www.registrar.umd.edu/current/registration/registration.html#waithold">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# </a>)
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST126', '0101', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="one columns"><img aria-hidden="true" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/></div>
# <div class="section-day-time-group push_one five columns">
# <span class="elms-class-message">Class time/details on ELMS</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <span class="class-room">ONLINE</span>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="section delivery-f2f">
# <input name="sectionId" type="hidden" value="0102"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0102
# 									</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Instructor: TBA</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">54</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">32</span>,
# 											</span>
# <span class="waitlist">
# <a href="http://www.registrar.umd.edu/current/registration/registration.html#waithold">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# </a>)
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST126', '0102', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="section-day-time-group push_two five columns">
# <span class="section-days">TuTh</span>
# <span class="class-start-time">9:30am</span> - <span class="class-end-time">10:45am</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <a style="color:#A81919;" target="_blank"><span class="building-code">CCC</span>
# <span class="class-room">1205</span></a>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="section delivery-online">
# <input name="sectionId" type="hidden" value="0103"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0103
# 									</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Jennifer Proctor</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">45</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">16</span>,
# 											</span>
# <span class="waitlist">
# <a href="http://www.registrar.umd.edu/current/registration/registration.html#waithold">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# </a>)
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST126', '0103', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png">
# </img></a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="one columns"><img aria-hidden="true" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/></div>
# <div class="section-day-time-group push_one five columns">
# <span class="section-days">TuTh</span>
# <span class="class-start-time">3:30pm</span> - <span class="class-end-time">4:45pm</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <span class="class-room">ONLINE</span>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="section delivery-online">
# <input name="sectionId" type="hidden" value="0104"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0104
# 									</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">P Kshetry</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">45</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">14</span>,
# 											</span>
# <span class="waitlist">
# <a href="http://www.registrar.umd.edu/current/registration/registration.html#waithold">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# </a>)
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST126', '0104', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="one columns"><img aria-hidden="true" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/></div>
# <div class="section-day-time-group push_one five columns">
# <span class="elms-class-message">Class time/details on ELMS</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <span class="class-room">ONLINE</span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </fieldset>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="course" id="INST151">
# <input name="courseId" type="hidden" value="INST151"/>
# <div class="row">
# <div class="course-id-container one columns">
# <div class="course-id">INST151</div>
# </div>
# <div class="course-info-container eleven columns">
# <div class="course-basic-info-container sixteen colgrid">
# <div class="row">
# <div class="thirteen columns">
# <span class="course-title">Becoming A Social Media Influencer</span>
# </div>
# <div class="two columns">
# <fieldset class="syllabus-fieldset">
# <legend>
# <a class="toggle-syllabus-link" href="">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-e"></span>
# <span class="toggle-sections-link-text">Syllabus Repository  </span>
# <span>(0)</span>
# <input name="courseId" type="hidden" value="INST151"/>
# </a>
# </legend>
# <div id="INST151-syllabus-container"></div>
# </fieldset>
# </div>
# <!-- @@@@@@@@@ -->
# <div class="course-action-links-container one columns">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST151', '*', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# </div>
# </div>
# <div class="course-stats-container row clearfix">
# <div class="course-credits-group two columns">
# <div>
# <span class="course-info-label">Credits:</span>
# <span class="course-min-credits">3</span>
# </div>
# </div>
# <div class="grading-method-group five columns">
# <div>
# <span class="course-info-label"><abbr title="Grading Method"><span>Grad Meth</span></abbr></span>:
# 														<span class="grading-method">
# <abbr title="Regular, Pass-Fail, Audit"><span>Reg, P-F, Aud</span></abbr>
# </span>
# </div>
# </div>
# <div class="core-codes-group two columns">
# <div>
# </div>
# </div>
# <div class="gen-ed-codes-group six columns">
# <div>
# <span class="course-info-label"><abbr title="General Education"><span>GenEd</span></abbr></span>:
#
#
#
#
#
#
# 																	<span class="course-subcategory">
# <a href="#" title="Distributive Studies - Scholarship in Practice">DSSP</a></span>
# </div>
# </div>
# </div>
# </div>
# <div class="approved-course-texts-container">
# <div class="row">
# <div class="twelve columns">
# <div class="approved-course-text"><div><div><div><strong>Credit only granted for:</strong> INST408N or INST151. </div><div><strong>Formerly:</strong> INST408N.</div></div></div></div>
# </div>
# </div>
# <div class="row">
# <div class="twelve columns">
# <div class="approved-course-text">Teaches students how to create, grow, and manage influential social media accounts. Topics will include tools for content creation, analyzing and strategizing with analytics, building community, and defining their niche and approach.</div>
# </div>
# </div>
# </div>
# <div class="course-texts-container">
# </div>
# <div class="toggle-sections-link-container">
# <div class="row">
# <div class="sections-fieldset-container twelve columns">
# <fieldset class="sections-fieldset sections-displayed">
# <legend>
# <a class="toggle-sections-link" href="/soc/202208/INST/INST151?teachingCenter=ALL">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-s"></span><span class="toggle-sections-link-text">Hide Sections</span>
# </a>
# <span class="hidden section-deliveryFilter">
# <a class="hidden delivery-all deliveryFilter deliveryFilter--selected" href="javascript:void(0)" onclick="SocJs.showAllSections(this);">All Sections</a>
# <a class="hidden delivery-f2f deliveryFilter" href="javascript:void(0)" onclick="SocJs.showF2FSections(this);">Face-to-Face</a>
# <a class="hidden delivery-blended deliveryFilter" href="javascript:void(0)" onclick="SocJs.showBlendedSections(this);"><img aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/blended_icon.png" width="20px"/>  Blended Learning</a>
# <a class="hidden delivery-online deliveryFilter" href="javascript:void(0)" onclick="SocJs.showOnlineSections(this);"><img aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/> Online</a>
# </span>
# </legend>
# <div class="sections-container">
# <div class="sections sixteen colgrid">
# <div class="section delivery-online">
# <input name="sectionId" type="hidden" value="0101"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0101
# 									</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Jennifer Golbeck</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">100</span>,
# 											</span>
# <span class="open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">0</span>,
# 											</span>
# <span class="waitlist has-waitlist">
# <a href="http://www.registrar.umd.edu/current/registration/registration.html#waithold">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">27</span>
# <span class="seats-info-label">Holdfile:</span>
# <span class="waitlist-count">0</span>
# </a>)
#
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST151', '0101', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="one columns"><img aria-hidden="true" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/></div>
# <div class="section-day-time-group push_one five columns">
# <span class="elms-class-message">Class time/details on ELMS</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <span class="class-room">ONLINE</span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </fieldset>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="course" id="INST152">
# <input name="courseId" type="hidden" value="INST152"/>
# <div class="row">
# <div class="course-id-container one columns">
# <div class="course-id">INST152</div>
# </div>
# <div class="course-info-container eleven columns">
# <div class="course-basic-info-container sixteen colgrid">
# <div class="row">
# <div class="thirteen columns">
# <span class="course-title">"Fake Checking": Battling Misinformation and Disinformation in the Real World</span>
# </div>
# <div class="two columns">
# <fieldset class="syllabus-fieldset">
# <legend>
# <a class="toggle-syllabus-link" href="">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-e"></span>
# <span class="toggle-sections-link-text">Syllabus Repository  </span>
# <span>(2)</span>
# <input name="courseId" type="hidden" value="INST152"/>
# </a>
# </legend>
# <div id="INST152-syllabus-container"></div>
# </fieldset>
# </div>
# <!-- @@@@@@@@@ -->
# <div class="course-action-links-container one columns">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST152', '*', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# </div>
# </div>
# <div class="course-stats-container row clearfix">
# ...
# <div class="sections sixteen colgrid">
# <div class="section delivery-online">
# <input name="sectionId" type="hidden" value="0101"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0101
# 									</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Paul Jaeger</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">5</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">3</span>,
# 											</span>
# <span class="waitlist">
# <a href="http://www.registrar.umd.edu/current/registration/registration.html#waithold">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# </a>)
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST878B', '0101', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="one columns"><img aria-hidden="true" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/></div>
# <div class="section-day-time-group push_one five columns">
# <span class="elms-class-message">Class time/details on ELMS</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <span class="class-room">ONLINE</span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </fieldset>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="course" id="INST878C">
# <input name="courseId" type="hidden" value="INST878C"/>
# <div class="row">
# <div class="course-id-container one columns">
# <div class="course-id">INST878C</div>
# <div class="perm-req-message">(Perm Req)</div>
# </div>
# <div class="course-info-container eleven columns">
# <div class="course-basic-info-container sixteen colgrid">
# <div class="row">
# <div class="thirteen columns">
# <span class="course-title">Special Topics in Information Studies; Diverse Populations, Inclusion, and Information</span>
# </div>
# <div class="two columns">
# <fieldset class="syllabus-fieldset">
# <legend>
# <a class="toggle-syllabus-link" href="">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-e"></span>
# <span class="toggle-sections-link-text">Syllabus Repository  </span>
# <span>(0)</span>
# <input name="courseId" type="hidden" value="INST878C"/>
# </a>
# </legend>
# <div id="INST878C-syllabus-container"></div>
# </fieldset>
# </div>
# <!-- @@@@@@@@@ -->
# <div class="course-action-links-container one columns">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST878C', '*', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# </div>
# </div>
# <div class="course-stats-container row clearfix">
# <div class="course-credits-group two columns">
# <div>
# <span class="course-info-label">Credits:</span>
# <span class="course-min-credits">3</span>
# </div>
# </div>
# <div class="grading-method-group five columns">
# <div>
# <span class="course-info-label"><abbr title="Grading Method"><span>Grad Meth</span></abbr></span>:
# 														<span class="grading-method">
# <abbr title="Regular, Audit"><span>Reg, Aud</span></abbr>
# </span>
# </div>
# </div>
# <div class="core-codes-group two columns">
# <div>
# </div>
# </div>
# <div class="gen-ed-codes-group six columns">
# <div>
# </div>
# </div>
# </div>
# </div>
# <div class="course-texts-container">
# </div>
# <div class="toggle-sections-link-container">
# <div class="row">
# <div class="sections-fieldset-container twelve columns">
# <fieldset class="sections-fieldset sections-displayed">
# <legend>
# <a class="toggle-sections-link" href="/soc/202208/INST/INST878C?teachingCenter=ALL">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-s"></span><span class="toggle-sections-link-text">Hide Sections</span>
# </a>
# <span class="hidden section-deliveryFilter">
# <a class="hidden delivery-all deliveryFilter deliveryFilter--selected" href="javascript:void(0)" onclick="SocJs.showAllSections(this);">All Sections</a>
# <a class="hidden delivery-f2f deliveryFilter" href="javascript:void(0)" onclick="SocJs.showF2FSections(this);">Face-to-Face</a>
# <a class="hidden delivery-blended deliveryFilter" href="javascript:void(0)" onclick="SocJs.showBlendedSections(this);"><img aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/blended_icon.png" width="20px"/>  Blended Learning</a>
# <a class="hidden delivery-online deliveryFilter" href="javascript:void(0)" onclick="SocJs.showOnlineSections(this);"><img aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/> Online</a>
# </span>
# </legend>
# <div class="sections-container">
# <div class="sections sixteen colgrid">
# <div class="section delivery-online">
# <input name="sectionId" type="hidden" value="0101"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0101
# 									</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Instructor: TBA</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">5</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">3</span>,
# 											</span>
# <span class="waitlist">
# <a href="http://www.registrar.umd.edu/current/registration/registration.html#waithold">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# </a>)
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST878C', '0101', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="one columns"><img aria-hidden="true" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/></div>
# <div class="section-day-time-group push_one five columns">
# <span class="elms-class-message">Class time/details on ELMS</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <span class="class-room">ONLINE</span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </fieldset>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="course" id="INST878E">
# <input name="courseId" type="hidden" value="INST878E"/>
# <div class="row">
# <div class="course-id-container one columns">
# <div class="course-id">INST878E</div>
# </div>
# <div class="course-info-container eleven columns">
# <div class="course-basic-info-container sixteen colgrid">
# <div class="row">
# <div class="thirteen columns">
# <span class="course-title">Special Topics in Information Studies; Achieving Organizational Excellence</span>
# </div>
# <div class="two columns">
# <fieldset class="syllabus-fieldset">
# <legend>
# <a class="toggle-syllabus-link" href="">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-e"></span>
# <span class="toggle-sections-link-text">Syllabus Repository  </span>
# <span>(0)</span>
# <input name="courseId" type="hidden" value="INST878E"/>
# </a>
# </legend>
# <div id="INST878E-syllabus-container"></div>
# </fieldset>
# </div>
# <!-- @@@@@@@@@ -->
# <div class="course-action-links-container one columns">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST878E', '*', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# </div>
# </div>
# <div class="course-stats-container row clearfix">
# <div class="course-credits-group two columns">
# <div>
# <span class="course-info-label">Credits:</span>
# <span class="course-min-credits">3</span>
# </div>
# </div>
# <div class="grading-method-group five columns">
# <div>
# <span class="course-info-label"><abbr title="Grading Method"><span>Grad Meth</span></abbr></span>:
# 														<span class="grading-method">
# <abbr title="Regular, Audit"><span>Reg, Aud</span></abbr>
# </span>
# </div>
# </div>
# <div class="core-codes-group two columns">
# <div>
# </div>
# </div>
# <div class="gen-ed-codes-group six columns">
# <div>
# </div>
# </div>
# </div>
# </div>
# <div class="course-texts-container">
# </div>
# <div class="toggle-sections-link-container">
# <div class="row">
# <div class="sections-fieldset-container twelve columns">
# <fieldset class="sections-fieldset sections-displayed">
# <legend>
# <a class="toggle-sections-link" href="/soc/202208/INST/INST878E?teachingCenter=ALL">
# <span class="toggle-sections-arrow ui-icon ui-icon-triangle-1-s"></span><span class="toggle-sections-link-text">Hide Sections</span>
# </a>
# <span class="hidden section-deliveryFilter">
# <a class="hidden delivery-all deliveryFilter deliveryFilter--selected" href="javascript:void(0)" onclick="SocJs.showAllSections(this);">All Sections</a>
# <a class="hidden delivery-f2f deliveryFilter" href="javascript:void(0)" onclick="SocJs.showF2FSections(this);">Face-to-Face</a>
# <a class="hidden delivery-blended deliveryFilter" href="javascript:void(0)" onclick="SocJs.showBlendedSections(this);"><img aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/blended_icon.png" width="20px"/>  Blended Learning</a>
# <a class="hidden delivery-online deliveryFilter" href="javascript:void(0)" onclick="SocJs.showOnlineSections(this);"><img aria-hidden="true" class="deliveryIcon" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/> Online</a>
# </span>
# </legend>
# <div class="sections-container">
# <div class="sections sixteen colgrid">
# <div class="section delivery-online">
# <input name="sectionId" type="hidden" value="0101"/>
# <div class="section-info-container">
# <div class="row">
# <div class="section-id-container two columns">
# <span class="section-id">
# 										0101
# 									</span>
# </div>
# <div class="section-instructors-container five columns">
# <span class="section-instructors">
# <span class="section-instructor">Instructor: TBA</span>
# </span>
# </div>
# <div class="seats-info-group six columns">
# <div>
# <span class="section-info-label">Seats</span>
# <span class="seats-info">
# <span class="total-seats">
# 												(<span class="seats-info-label">Total:</span>
# <span class="total-seats-count">5</span>,
# 											</span>
# <span class="open-seats has-open-seats">
# <span class="seats-info-label">Open:</span>
# <span class="open-seats-count">5</span>,
# 											</span>
# <span class="waitlist">
# <a href="http://www.registrar.umd.edu/current/registration/registration.html#waithold">
# <span class="seats-info-label"> Waitlist:</span>
# <span class="waitlist-count">0</span>
# </a>)
#
#
# 												</span>
# </span>
# </div>
# </div>
# <div class="two columns section-action-links-container2">
# <a class="saved-course-section-toggle-link" href="javascript:void(0)" onclick="SocJs.saveSection(this, 'INST878E', '0101', '/soc');" title="Add to My Saved List">
# <img src="/soc/resources/images/unsaved-star.png"/>
# </a>
# <a class="bookstore-link" href="#">
# <img alt="Bookstore" src="/soc/resources/images/bookstore.png" title="Bookstore"/>
# </a>
# </div>
# </div>
# </div> <!-- end section-info-container -->
# <div class="class-days-container">
# <div class="row">
# <div class="one columns"><img aria-hidden="true" height="16px" src="/soc/resources/images/online_icon.png" width="20px"/></div>
# <div class="section-day-time-group push_one five columns">
# <span class="elms-class-message">Class time/details on ELMS</span>
# </div>
# <div class="section-class-building-group push_one three columns">
# <span class="class-building">
# <span class="class-room">ONLINE</span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </fieldset>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>]
# [{'Code': 'INST101',
#   'Title': 'Bits and Bytes of Computer and Information Sciences',
#   'Description': 'Restriction: For first time freshmen and first time transfer students. Cross-listed with: CMSC100. Credit only granted for: CMSC100 or INST101.Students are introduced to the fields (and disciplines) of computer science and information science within a small classroom setting. They will learn to make a successful transition from high school to the university, while exploring study skills, student success plans and research opportunities.',
#   'Prereqs': 'None',
#   'Credits': '1'},
#  {'Code': 'INST104',
#   'Title': 'Design Across Campus',
#   'Description': 'What is design, who does it, and how is it done? There is no one answer to this question--it depends on who you ask. The answers to these questions vary across disciplines and across the University campus. This course, designed with modules from contributors in UMD programs including Information Studies, Human-Computer Interaction, Graphic Design, Immersive Media Arts, Journalism, Architecture, Landscape Architecture, Engineering, and Policy, will introduce students to the goals and values, approaches, skills, and practices of diverse fields of design. It will enable students to identify grand challenges in design and serve as a sorting hat to help students find a design practice that matches their own values, approaches, skills and goals.',
#   'Prereqs': 'None',
#   'Credits': '3'},
#  {'Code': 'INST123',
#   'Title': 'Databases for All',
#   'Description': 'Restriction: Must not have completed or be currently taking INST327 or BMGT402.An introduction to relational databases for students with no previous programming experience. Provides a means for students of diverse backgrounds to successfully learn how to store, retrieve, and maintain data in relational databases. Topics include a brief comparison of database systems with an emphasis on relational databases, fundamental relational database concepts, and data types. Includes technical approaches to accessing information stored in relational databases.',
#   'Prereqs': 'None',
#   'Credits': '3'},
#  {'Code': 'INST126',
#   'Title': 'Introduction to Programming for Information Science',
#   'Description': 'An introduction to computer programming for students with very limited or no previous programming experience. Topics include fundamental programming concepts such as variables, data types, assignments, arrays, conditionals, loops, functions, and I/O operations.',
#   'Prereqs': 'Prerequisite: Math placement of STAT100 or higher. Restriction: Must not have completed INST326; and must be in Information Science, Technology and Information Design, or Social Data Science programs.',
#   'Credits': '3'},
#  {'Code': 'INST151',
#   'Title': 'Becoming A Social Media Influencer',
#   'Description': 'Credit only granted for: INST408N or INST151. Formerly: INST408N.Teaches students how to create, grow, and manage influential social media accounts. Topics will include tools for content creation, analyzing and strategizing with analytics, building community, and defining their niche and approach.',
#   'Prereqs': 'None',
#   'Credits': '3'}]

# %% [markdown]
# We can then turn this into a dataframe for analysis! :) This is actually how I made the data file for our exercises this semester.

# %%
# turn into pandas df and show
course_list_df = pd.DataFrame(course_list)
course_list_df.head()
# Out:
#       Code                                              Title  \
# 0  INST101  Bits and Bytes of Computer and Information Sci...
# 1  INST104                               Design Across Campus
# 2  INST123                                  Databases for All
# 3  INST126  Introduction to Programming for Information Sc...
# 4  INST151                 Becoming A Social Media Influencer
#
#                                          Description  \
# 0  Restriction: For first time freshmen and first...
# 1  What is design, who does it, and how is it don...
# 2  Restriction: Must not have completed or be cur...
# 3  An introduction to computer programming for st...
# 4  Credit only granted for: INST408N or INST151. ...
#
#                                              Prereqs Credits
# 0                                               None       1
# 1                                               None       3
# 2                                               None       3
# 3  Prerequisite: Math placement of STAT100 or hig...       3
# 4                                               None       3

# %% [markdown]
# ## Using urllib and the json library to parse json data from another computer

# %%
response2 = urllib.request.urlopen('http://joelchan.me/contacts.json') # this is my server computer!

# %%
rawdata = response2.read()
parsedcontacts = json.loads(rawdata)
parsedcontacts
# Out:
# [{'name': 'Chuck',
#   'phone': {'type': 'intl', 'number': '+1 734 303 4456'},
#   'email': {'email': 'ck@umd.edu', 'hide': 'yes'}},
#  {'name': 'Joel',
#   'phone': {'type': 'local', 'number': '479 647 9905'},
#   'email': {'email': 'jc@umd.edu', 'hide': 'no'}},
#  {'name': 'Zara',
#   'phone': {'type': 'local', 'number': '678 321 4456'},
#   'email': {'email': 'zh@umd.edu', 'hide': 'yes'}}]

# %%
first_item = parsedcontacts[0]

# %%
first_item
# Out:
# {'name': 'Chuck',
#  'phone': {'type': 'intl', 'number': '+1 734 303 4456'},
#  'email': {'email': 'ck@umd.edu', 'hide': 'yes'}}

# %%
first_item.get("name")
# Out:
# 'Chuck'

# %%
first_item["name"]
# Out:
# 'Chuck'

# %%
contacts = pd.read_json(rawdata)

# %%
contacts
# Out:
#     name                                          phone  \
# 0  Chuck  {'type': 'intl', 'number': '+1 734 303 4456'}
# 1   Joel    {'type': 'local', 'number': '479 647 9905'}
# 2   Zara    {'type': 'local', 'number': '678 321 4456'}
#
#                                     email
# 0  {'email': 'ck@umd.edu', 'hide': 'yes'}
# 1   {'email': 'jc@umd.edu', 'hide': 'no'}
# 2  {'email': 'zh@umd.edu', 'hide': 'yes'}
